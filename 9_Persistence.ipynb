# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'Football'}, config=config1)
# Out:
# {'topic': 'Football',
#  'joke': 'Why did the football player bring a ladder to the game?\n\nBecause he heard the coach wanted him to *reach new heights* with his diving!',
#  'explanation': 'This joke is a classic play on words, specifically an idiom:\n\n1.  **The Idiom:** "To reach new heights" is a common idiom meaning to achieve greater success, improve significantly, perform exceptionally well, or surpass previous achievements. When a coach tells a player to "reach new heights," they mean they want the player to improve their game, score more, or perform better than ever before.\n\n2.  **The Literal Interpretation:** The football player in the joke comically misunderstands this idiom. He takes "reach new heights" literally, thinking he needs to physically get higher. A ladder is, of course, a tool used to physically reach higher places.\n\n3.  **The "Diving" Element:** The phrase "with his diving" adds another layer. While "diving" in football can refer to a specific action (like a header, a tackle where you launch yourself, or even feigning injury), it also evokes the image of someone launching themselves through the air. This further reinforces the *literal* idea of gaining height or elevation, making the player\'s misunderstanding even funnier.\n\n**In essence:** The humor comes from the player\'s absurdly literal interpretation of a common motivational phrase, leading him to bring an inappropriate (but logically consistent with his misunderstanding) item to the game. It\'s a pun combined with a bit of situational irony.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'Football', 'joke': 'Why did the football player bring a ladder to the game?\n\nBecause he heard the coach wanted him to *reach new heights* with his diving!', 'explanation': 'This joke is a classic play on words, specifically an idiom:\n\n1.  **The Idiom:** "To reach new heights" is a common idiom meaning to achieve greater success, improve significantly, perform exceptionally well, or surpass previous achievements. When a coach tells a player to "reach new heights," they mean they want the player to improve their game, score more, or perform better than ever before.\n\n2.  **The Literal Interpretation:** The football player in the joke comically misunderstands this idiom. He takes "reach new heights" literally, thinking he needs to physically get higher. A ladder is, of course, a tool used to physically reach higher places.\n\n3.  **The "Diving" Element:** The phrase "with his diving" adds another layer. While "diving" in football can refer to a specific action (like a header, a tackle where you launch yourself, or even feigning injury), it also evokes the image of someone launching themselves through the air. This further reinforces the *literal* idea of gaining height or elevation, making the player\'s misunderstanding even funnier.\n\n**In essence:** The humor comes from the player\'s absurdly literal interpretation of a common motivational phrase, leading him to bring an inappropriate (but logically consistent with his misunderstanding) item to the game. It\'s a pun combined with a bit of situational irony.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1875aa-dc45-6731-8002-930885843701'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-24T12:24:55.732817+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1875aa-95bd-67c3-8001-c57805ff687e'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'Football', 'joke': 'Why did the football player bring a ladder to the game?\n\nBecause he heard the coach wanted him to *reach new heights* with his diving!', 'explanation': 'This joke is a classic play on words, specifically an idiom:\n\n1.  **The Idiom:** "To reach new heights" is a common idiom meaning to achieve greater success, improve significantly, perform exceptionally well, or surpass previous achievements. When a coach tells a player to "reach new heights," they mean they want the player to improve their game, score more, or perform better than ever before.\n\n2.  **The Literal Interpretation:** The football player in the joke comically misunderstands this idiom. He takes "reach new heights" literally, thinking he needs to physically get higher. A ladder is, of course, a tool used to physically reach higher places.\n\n3.  **The "Diving" Element:** The phrase "with his diving" adds another layer. While "diving" in football can refer to a specific action (like a header, a tackle where you launch yourself, or even feigning injury), it also evokes the image of someone launching themselves through the air. This further reinforces the *literal* idea of gaining height or elevation, making the player\'s misunderstanding even funnier.\n\n**In essence:** The humor comes from the player\'s absurdly literal interpretation of a common motivational phrase, leading him to bring an inappropriate (but logically consistent with his misunderstanding) item to the game. It\'s a pun combined with a bit of situational irony.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1875aa-dc45-6731-8002-930885843701'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-24T12:24:55.732817+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1875aa-95bd-67c3-8001-c57805ff687e'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Football', 'joke': 'Why did the football player bring a ladder to the game?\n\nBecause he heard the coach wanted him to *reach new heights* with his diving!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1875aa-95bd-67c3-8001-c57805ff687e'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-24T12:24:48.337094+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1875aa-3b06-6de2-8000-9202f2426574'}}, tasks=(PregelTask(id='d990f4e6-2171-500d-f699-e792facf1bce', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a classic play on words, specifically an idiom:\n\n1.  **The Idiom:** "To reach new heights" is a common idiom meaning to achieve greater success, improve significantly, perform exceptionally well, or surpass previous achievements. When a coach tells a player to "reach new heights," they mean they want the player to improve their game, score more, or perform better than ever before.\n\n2.  **The Literal Interpretation:** The football player in the joke comically misunderstands this idiom. He takes "reach new heights" literally, thinking he needs to physically get higher. A ladder is, of course, a tool used to physically reach higher places.\n\n3.  **The "Diving" Element:** The phrase "with his diving" adds another layer. While "diving" in football can refer to a specific action (like a header, a tackle where you launch yourself, or even feigning injury), it also evokes the image of someone launching themselves through the air. This further reinforces the *literal* idea of gaining height or elevation, making the player\'s misunderstanding even funnier.\n\n**In essence:** The humor comes from the player\'s absurdly literal interpretation of a common motivational phrase, leading him to bring an inappropriate (but logically consistent with his misunderstanding) item to the game. It\'s a pun combined with a bit of situational irony.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Football'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1875aa-3b06-6de2-8000-9202f2426574'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-24T12:24:38.825110+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1875aa-3af3-6527-bfff-ee522e9df3fd'}}, tasks=(PregelTask(id='8cf80737-fe81-d712-d8ac-ab0de6df8096', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the football player bring a ladder to the game?\n\nBecause he heard the coach wanted him to *reach new heights* with his diving!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1875aa-3af3-6527-bfff-ee522e9df3fd'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-24T12:24:38.817104+00:00', parent_config=None, tasks=(PregelTask(id='76049487-6214-0f7d-c7e9-a9012541542e', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Football'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'Cricket'}, config=config2)
# Out:
# {'topic': 'Cricket',
#  'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!',
#  'explanation': 'This joke is a classic pun that plays on the double meaning of the word "duck."\n\nHere\'s the breakdown:\n\n1.  **The Animal Duck:** The joke sets up the image of an actual, literal duck trying to play cricket. This is the first, straightforward meaning.\n\n2.  **"Getting out for a duck" (Cricket Term):** In the sport of cricket, when a batsman is dismissed (gets "out") without scoring any runs at all (i.e., they score zero), it\'s called getting "out for a duck." This term is thought to have originated because the score of zero resembles a "duck\'s egg."\n\n**The Humor:**\n\nThe joke is funny because it pretends the *literal duck* (the animal) is being kicked off the team because it keeps performing poorly, which in cricket is *also called* getting "out for a duck."\n\nSo, the duck isn\'t just a bad player; its failure is *literally* named after what it is! It\'s a silly, unexpected twist based on the identical sound and spelling of the word "duck" in two very different contexts.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!', 'explanation': 'This joke is a classic pun that plays on the double meaning of the word "duck."\n\nHere\'s the breakdown:\n\n1.  **The Animal Duck:** The joke sets up the image of an actual, literal duck trying to play cricket. This is the first, straightforward meaning.\n\n2.  **"Getting out for a duck" (Cricket Term):** In the sport of cricket, when a batsman is dismissed (gets "out") without scoring any runs at all (i.e., they score zero), it\'s called getting "out for a duck." This term is thought to have originated because the score of zero resembles a "duck\'s egg."\n\n**The Humor:**\n\nThe joke is funny because it pretends the *literal duck* (the animal) is being kicked off the team because it keeps performing poorly, which in cricket is *also called* getting "out for a duck."\n\nSo, the duck isn\'t just a bad player; its failure is *literally* named after what it is! It\'s a silly, unexpected twist based on the identical sound and spelling of the word "duck" in two very different contexts.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ac-3cc5-619a-8002-5d0a165fb627'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-24T12:25:32.694978+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-fb08-6e75-8001-61f10f35b9c1'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!', 'explanation': 'This joke is a classic pun that plays on the double meaning of the word "duck."\n\nHere\'s the breakdown:\n\n1.  **The Animal Duck:** The joke sets up the image of an actual, literal duck trying to play cricket. This is the first, straightforward meaning.\n\n2.  **"Getting out for a duck" (Cricket Term):** In the sport of cricket, when a batsman is dismissed (gets "out") without scoring any runs at all (i.e., they score zero), it\'s called getting "out for a duck." This term is thought to have originated because the score of zero resembles a "duck\'s egg."\n\n**The Humor:**\n\nThe joke is funny because it pretends the *literal duck* (the animal) is being kicked off the team because it keeps performing poorly, which in cricket is *also called* getting "out for a duck."\n\nSo, the duck isn\'t just a bad player; its failure is *literally* named after what it is! It\'s a silly, unexpected twist based on the identical sound and spelling of the word "duck" in two very different contexts.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ac-3cc5-619a-8002-5d0a165fb627'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-24T12:25:32.694978+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-fb08-6e75-8001-61f10f35b9c1'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-fb08-6e75-8001-61f10f35b9c1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-24T12:25:25.802149+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b18d-67bb-8000-3038b0a54770'}}, tasks=(PregelTask(id='12c905e7-a808-00a8-a656-c055711823c8', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a classic pun that plays on the double meaning of the word "duck."\n\nHere\'s the breakdown:\n\n1.  **The Animal Duck:** The joke sets up the image of an actual, literal duck trying to play cricket. This is the first, straightforward meaning.\n\n2.  **"Getting out for a duck" (Cricket Term):** In the sport of cricket, when a batsman is dismissed (gets "out") without scoring any runs at all (i.e., they score zero), it\'s called getting "out for a duck." This term is thought to have originated because the score of zero resembles a "duck\'s egg."\n\n**The Humor:**\n\nThe joke is funny because it pretends the *literal duck* (the animal) is being kicked off the team because it keeps performing poorly, which in cricket is *also called* getting "out for a duck."\n\nSo, the duck isn\'t just a bad player; its failure is *literally* named after what it is! It\'s a silly, unexpected twist based on the identical sound and spelling of the word "duck" in two very different contexts.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b18d-67bb-8000-3038b0a54770'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-24T12:25:18.096991+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b17d-6289-bfff-2372a6626164'}}, tasks=(PregelTask(id='5fbf5aa7-d80d-03a4-0b89-df585036e46a', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b17d-6289-bfff-2372a6626164'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-24T12:25:18.090304+00:00', parent_config=None, tasks=(PregelTask(id='a95c111a-d148-d5d6-d60e-f7b672c15c4f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Cricket'}),), interrupts=())]

# %% [markdown]
# ###
# Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f15d969-8ed6-683c-8000-0c7a2f030ccd"}})
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_id': '1f15d969-8ed6-683c-8000-0c7a2f030ccd'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!', 'explanation': 'This joke is a classic pun that plays on the double meaning of the word "duck."\n\nHere\'s the breakdown:\n\n1.  **The Animal Duck:** The joke sets up the image of an actual, literal duck trying to play cricket. This is the first, straightforward meaning.\n\n2.  **"Getting out for a duck" (Cricket Term):** In the sport of cricket, when a batsman is dismissed (gets "out") without scoring any runs at all (i.e., they score zero), it\'s called getting "out for a duck." This term is thought to have originated because the score of zero resembles a "duck\'s egg."\n\n**The Humor:**\n\nThe joke is funny because it pretends the *literal duck* (the animal) is being kicked off the team because it keeps performing poorly, which in cricket is *also called* getting "out for a duck."\n\nSo, the duck isn\'t just a bad player; its failure is *literally* named after what it is! It\'s a silly, unexpected twist based on the identical sound and spelling of the word "duck" in two very different contexts.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ac-3cc5-619a-8002-5d0a165fb627'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-24T12:25:32.694978+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-fb08-6e75-8001-61f10f35b9c1'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-fb08-6e75-8001-61f10f35b9c1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-24T12:25:25.802149+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b18d-67bb-8000-3038b0a54770'}}, tasks=(PregelTask(id='12c905e7-a808-00a8-a656-c055711823c8', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a classic pun that plays on the double meaning of the word "duck."\n\nHere\'s the breakdown:\n\n1.  **The Animal Duck:** The joke sets up the image of an actual, literal duck trying to play cricket. This is the first, straightforward meaning.\n\n2.  **"Getting out for a duck" (Cricket Term):** In the sport of cricket, when a batsman is dismissed (gets "out") without scoring any runs at all (i.e., they score zero), it\'s called getting "out for a duck." This term is thought to have originated because the score of zero resembles a "duck\'s egg."\n\n**The Humor:**\n\nThe joke is funny because it pretends the *literal duck* (the animal) is being kicked off the team because it keeps performing poorly, which in cricket is *also called* getting "out for a duck."\n\nSo, the duck isn\'t just a bad player; its failure is *literally* named after what it is! It\'s a silly, unexpected twist based on the identical sound and spelling of the word "duck" in two very different contexts.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b18d-67bb-8000-3038b0a54770'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-24T12:25:18.096991+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b17d-6289-bfff-2372a6626164'}}, tasks=(PregelTask(id='5fbf5aa7-d80d-03a4-0b89-df585036e46a', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b17d-6289-bfff-2372a6626164'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-24T12:25:18.090304+00:00', parent_config=None, tasks=(PregelTask(id='a95c111a-d148-d5d6-d60e-f7b672c15c4f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Cricket'}),), interrupts=())]

# %% [markdown]
# ###
# Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f15d969-8ed6-683c-8000-0c7a2f030ccd", "checkpoint_ns": ""}}, {'topic':'Tenis'})
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1875b0-8af1-6965-8000-b586483861f5'}}

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Tenis'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875b0-8af1-6965-8000-b586483861f5'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-07-24T12:27:28.266275+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f15d969-8ed6-683c-8000-0c7a2f030ccd'}}, tasks=(PregelTask(id='47efc80c-387f-9b08-be9c-dcabf3b9c120', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!', 'explanation': 'This joke is a classic pun that plays on the double meaning of the word "duck."\n\nHere\'s the breakdown:\n\n1.  **The Animal Duck:** The joke sets up the image of an actual, literal duck trying to play cricket. This is the first, straightforward meaning.\n\n2.  **"Getting out for a duck" (Cricket Term):** In the sport of cricket, when a batsman is dismissed (gets "out") without scoring any runs at all (i.e., they score zero), it\'s called getting "out for a duck." This term is thought to have originated because the score of zero resembles a "duck\'s egg."\n\n**The Humor:**\n\nThe joke is funny because it pretends the *literal duck* (the animal) is being kicked off the team because it keeps performing poorly, which in cricket is *also called* getting "out for a duck."\n\nSo, the duck isn\'t just a bad player; its failure is *literally* named after what it is! It\'s a silly, unexpected twist based on the identical sound and spelling of the word "duck" in two very different contexts.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ac-3cc5-619a-8002-5d0a165fb627'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-07-24T12:25:32.694978+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-fb08-6e75-8001-61f10f35b9c1'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-fb08-6e75-8001-61f10f35b9c1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-07-24T12:25:25.802149+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b18d-67bb-8000-3038b0a54770'}}, tasks=(PregelTask(id='12c905e7-a808-00a8-a656-c055711823c8', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a classic pun that plays on the double meaning of the word "duck."\n\nHere\'s the breakdown:\n\n1.  **The Animal Duck:** The joke sets up the image of an actual, literal duck trying to play cricket. This is the first, straightforward meaning.\n\n2.  **"Getting out for a duck" (Cricket Term):** In the sport of cricket, when a batsman is dismissed (gets "out") without scoring any runs at all (i.e., they score zero), it\'s called getting "out for a duck." This term is thought to have originated because the score of zero resembles a "duck\'s egg."\n\n**The Humor:**\n\nThe joke is funny because it pretends the *literal duck* (the animal) is being kicked off the team because it keeps performing poorly, which in cricket is *also called* getting "out for a duck."\n\nSo, the duck isn\'t just a bad player; its failure is *literally* named after what it is! It\'s a silly, unexpected twist based on the identical sound and spelling of the word "duck" in two very different contexts.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b18d-67bb-8000-3038b0a54770'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-07-24T12:25:18.096991+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b17d-6289-bfff-2372a6626164'}}, tasks=(PregelTask(id='5fbf5aa7-d80d-03a4-0b89-df585036e46a', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the duck get kicked off the cricket team?\n\nBecause he kept getting out for a duck!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1875ab-b17d-6289-bfff-2372a6626164'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-07-24T12:25:18.090304+00:00', parent_config=None, tasks=(PregelTask(id='a95c111a-d148-d5d6-d60e-f7b672c15c4f', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Cricket'}),), interrupts=())]

# %% [markdown]
# ###
# Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(30)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ✅ Step 3 executed

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)
# Out:
# 🔁 Re-running the graph to demonstrate fault tolerance...
#
# ✅ Final State: {'input': 'start', 'step1': 'done', 'step2': 'done'}
